# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data=pd.read_csv('Iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_setosa=data[data['Species']=='Iris-setosa']

# %%
iris_setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
avg_sepallength=data['SepalLengthCm'].mean()
avg_sepalwidth=data['SepalWidthCm'].mean()
avg_petallength=data['PetalLengthCm'].mean()
avg_petalwidth=data['PetalWidthCm'].mean()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Id'], data['SepalLengthCm'], linestyle='-',s color='blue', linewidth=2, label='Sepal Length')
plt.axhline(y=avg_sepallength, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('ID', fontsize=24)
plt.ylabel('Sepal Length', fontsize=24)
plt.title('Distribution of Sepal Length', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Id'], data['SepalWidthCm'], linestyle='-', color='blue', linewidth=2, label='Sepal Width')
plt.axhline(y=avg_sepalwidth, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('ID', fontsize=24)
plt.ylabel('Sepal Width', fontsize=24)
plt.title('Distribution of Sepal Width', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Id'], data['PetalLengthCm'], linestyle='-', color='blue', linewidth=2, label='Petal Length')
plt.axhline(y=avg_petallength, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('ID', fontsize=24)
plt.ylabel('Petal Length', fontsize=24)
plt.title('Distribution of Petal Length', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Id'], data['PetalWidthCm'], linestyle='-', color='blue', linewidth=2, label='Petal Width')
plt.axhline(y=avg_petalwidth, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('ID', fontsize=24)
plt.ylabel('Petal Width', fontsize=24)
plt.title('Distribution of Petal Width', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['SepalLengthCm'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Sepal Length', fontsize=16)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['SepalWidthCm'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Sepal Width', fontsize=16)
plt.xlabel('Sepal Width', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['PetalLengthCm'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Petal Length', fontsize=16)
plt.xlabel('Petal Length', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['PetalWidthCm'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Petal Width', fontsize=16)
plt.xlabel('Petal Width', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['SepalLengthCm'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Sepal Length', fontsize=16)
plt.xlabel('Sepal Length', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10728/2371283043.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['SepalLengthCm'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['SepalWidthCm'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Sepal Width', fontsize=16)
plt.xlabel('Sepal Width', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10728/65511779.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['SepalWidthCm'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['PetalLengthCm'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Petal Length', fontsize=16)
plt.xlabel('Petal Length', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10728/446773489.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['PetalLengthCm'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['PetalWidthCm'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Petal Width', fontsize=16)
plt.xlabel('Petal Width', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10728/2185946437.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['PetalWidthCm'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
iris_setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['SepalLengthCm'], y=data['SepalWidthCm'], hue='Species', data=data, palette='Set2', s=100)
plt.title('Scatter Plot of Sepal Length and Sepal Width by Species')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend(title='Species')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['PetalLengthCm'], y=data['PetalWidthCm'], hue='Species', data=data, palette='Set2', s=100)
plt.title('Scatter Plot of Petal Length and Petal Width by Species')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend(title='Species')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['SepalLengthCm'], y=data['PetalLengthCm'], hue='Species', data=data, palette='Set2', s=100)
plt.title('Scatter Plot of Sepal Length and Petal Length by Species')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend(title='Species')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['SepalWidthCm'], y=data['PetalWidthCm'], hue='Species', data=data, palette='Set2', s=100)
plt.title('Scatter Plot of Petal Width and Petal Width by Species')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.legend(title='Species')
