# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data=pd.read_csv('thermodynamics.csv')

# %%
data
# Out:
#      Step  Time   Volume  Temperature  Pressure  Kinetic  Potential   Energy  \
# 0       1   0.5  9194.67      292.503  2186.980  807.017   -2647.57 -1840.56
# 1       2   1.0  9302.99      293.461 -1257.580  809.662   -2629.40 -1819.74
# 2       3   1.5  9113.69      298.554 -3301.230  823.711   -2628.33 -1804.62
# 3       4   2.0  9198.38      302.528 -4657.720  834.677   -2629.24 -1794.57
# 4       5   2.5  9130.54      290.567  -710.977  801.676   -2591.64 -1789.97
# ..    ...   ...      ...          ...       ...      ...        ...      ...
# 194   195  97.5  9192.93      297.812  1134.070  821.665   -2642.75 -1821.08
# 195   196  98.0  9337.59      296.965 -1927.790  819.329   -2596.11 -1776.78
# 196   197  98.5  9119.26      309.630 -1103.290  854.271   -2628.38 -1774.11
# 197   198  99.0  9022.08      295.689  1359.530  815.807   -2629.19 -1813.38
# 198   199  99.5  8865.98      300.846  2497.790  830.037   -2690.37 -1860.33
#
#       Density
# 0    1.005360
# ...

# %%
data.head()
# Out:
#    Step  Time   Volume  Temperature  Pressure  Kinetic  Potential   Energy  \
# 0     1   0.5  9194.67      292.503  2186.980  807.017   -2647.57 -1840.56
# 1     2   1.0  9302.99      293.461 -1257.580  809.662   -2629.40 -1819.74
# 2     3   1.5  9113.69      298.554 -3301.230  823.711   -2628.33 -1804.62
# 3     4   2.0  9198.38      302.528 -4657.720  834.677   -2629.24 -1794.57
# 4     5   2.5  9130.54      290.567  -710.977  801.676   -2591.64 -1789.97
#
#     Density
# 0  1.005360
# 1  0.993652
# 2  1.014290
# 3  1.004950
# 4  1.012420

# %%
data.tail()
# Out:
#      Step  Time   Volume  Temperature  Pressure  Kinetic  Potential   Energy  \
# 194   195  97.5  9192.93      297.812   1134.07  821.665   -2642.75 -1821.08
# 195   196  98.0  9337.59      296.965  -1927.79  819.329   -2596.11 -1776.78
# 196   197  98.5  9119.26      309.630  -1103.29  854.271   -2628.38 -1774.11
# 197   198  99.0  9022.08      295.689   1359.53  815.807   -2629.19 -1813.38
# 198   199  99.5  8865.98      300.846   2497.79  830.037   -2690.37 -1860.33
#
#      Density
# 194  1.00555
# 195  0.98997
# 196  1.01367
# 197  1.02459
# 198  1.04263

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Step         199 non-null    int64
#  1   Time         199 non-null    float64
#  2   Volume       199 non-null    float64
#  3   Temperature  199 non-null    float64
#  4   Pressure     199 non-null    float64
#  5   Kinetic      199 non-null    float64
#  6   Potential    199 non-null    float64
#  7   Energy       199 non-null    float64
#  8   Density      199 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 14.1 KB

# %%
data.describe()
# Out:
#              Step        Time       Volume  Temperature     Pressure  \
# count  199.000000  199.000000   199.000000   199.000000   199.000000
# mean   100.000000   50.000000  9007.441307   298.888402   102.621241
# std     57.590508   28.795254   133.275619     7.676824  1825.960539
# min      1.000000    0.500000  8702.080000   275.620000 -4657.720000
# 25%     50.500000   25.250000  8920.410000   293.669500 -1146.185000
# 50%    100.000000   50.000000  9000.960000   299.139000   170.431000
# 75%    149.500000   74.750000  9111.105000   304.264000  1650.755000
# max    199.000000   99.500000  9444.950000   322.245000  4959.470000
#
#           Kinetic    Potential       Energy     Density
# count  199.000000   199.000000   199.000000  199.000000
# mean   824.634824 -2648.653166 -1824.018593    1.026478
# std     21.180391    27.242203    32.394689    0.015152
# min    760.436000 -2720.630000 -1912.660000    0.978717
# 25%    810.237000 -2670.345000 -1846.340000    1.014575
# ...

# %%
avg_volume=data['Volume'].mean()
avg_temp=data['Temperature'].mean()
avg_pressure=data['Pressure'].mean()
avg_kinetic=data['Kinetic'].mean()
avg_potential=data['Potential'].mean()
avg_energy=data['Energy'].mean()
avg_density=data['Density'].mean()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Time'], data['Volume'], linestyle='-', color='blue', linewidth=2, label='Volume')
plt.axhline(y=avg_volume, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('Time', fontsize=24)
plt.ylabel('Volume', fontsize=24)
plt.title('Time v Volume', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Time'], data['Temperature'], linestyle='-', color='blue', linewidth=2, label='Temperature')
plt.axhline(y=avg_temp, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('Time', fontsize=24)
plt.ylabel('Temperature', fontsize=24)
plt.title('Time v Temperature', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Time'], data['Pressure'], linestyle='-', color='blue', linewidth=2, label='Pressure')
plt.axhline(y=avg_temp, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('Time', fontsize=24)
plt.ylabel('Pressure', fontsize=24)
plt.title('Time v Pressure', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Time'], data['Kinetic'], linestyle='-', color='blue', linewidth=2, label='Kinetic')
plt.axhline(y=avg_kinetic, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('Time', fontsize=24)
plt.ylabel('Kinetic', fontsize=24)
plt.title('Time v Kinetic', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Time'], data['Potential'], linestyle='-', color='blue', linewidth=2, label='Potential')
plt.axhline(y=avg_potential, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('Time', fontsize=24)
plt.ylabel('Potential', fontsize=24)
plt.title('Time v Potential', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Time'], data['Energy'], linestyle='-', color='blue', linewidth=2, label='Energy')
plt.axhline(y=avg_energy, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('Time', fontsize=24)
plt.ylabel('Energy', fontsize=24)
plt.title('Time v Energy', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.plot(data['Time'], data['Density'], linestyle='-', color='blue', linewidth=2, label='Density')
plt.axhline(y=avg_density, color='r', linestyle='--', linewidth=3, label='Avg')
plt.xlabel('Time', fontsize=24)
plt.ylabel('Density', fontsize=24)
plt.title('Time v Density', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['Volume'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Volume', fontsize=16)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['Temperature'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Temperature', fontsize=16)
plt.xlabel('Temperature', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['Pressure'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Pressure', fontsize=16)
plt.xlabel('Pressure', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['Kinetic'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Kinetic', fontsize=16)
plt.xlabel('Kinetic', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['Potential'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Potential', fontsize=16)
plt.xlabel('Potential', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['Energy'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Energy', fontsize=16)
plt.xlabel('Energy', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.hist(data['Density'], bins=20, color='cyan', edgecolor='black', alpha=0.7)
plt.title('Histogram of Density', fontsize=16)
plt.xlabel('Density', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Volume'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Volume', fontsize=16)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12669/4233648388.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Volume'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Temperature'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Temperature', fontsize=16)
plt.xlabel('Temperature', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12669/3334002006.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Temperature'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Pressure'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Pressure', fontsize=16)
plt.xlabel('Pressure', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12669/2894404536.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Pressure'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Kinetic'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Kinetic', fontsize=16)
plt.xlabel('Kinetic', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12669/895314072.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Kinetic'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Potential'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Potential', fontsize=16)
plt.xlabel('Potential', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12669/1669206201.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Potential'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Energy'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Energy', fontsize=16)
plt.xlabel('Energyl', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12669/2605665274.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Energy'], shade=True, color="orange", alpha=0.7, lw=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Density'], shade=True, color="orange", alpha=0.7, lw=2)
plt.title('KDE Plot for Density', fontsize=16)
plt.xlabel('Density', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12669/2200515847.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Density'], shade=True, color="orange", alpha=0.7, lw=2)
